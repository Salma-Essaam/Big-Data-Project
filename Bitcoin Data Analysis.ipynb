# %% [markdown]
# ## Imports

# %%
import findspark
findspark.init('/home/SalmaEssam/spark-3.5.3-bin-hadoop3')




from pyspark.sql.functions import max
from pyspark.sql import SparkSession
from pyspark.sql.functions import col, format_number
from pyspark.sql.functions import mean, stddev
from pyspark.sql.functions import countDistinct
from pyspark.sql.functions import year, month
from pyspark.sql.functions import dayofyear , dayofmonth
from pyspark.sql.functions import min, max

# %% [markdown]
# ## Spark Session

# %%
spark = SparkSession.builder.appName('Project').getOrCreate()
# Out:
# 24/12/24 14:57:47 WARN Utils: Your hostname, mohamedsalah-VirtualBox resolves to a loopback address: 127.0.1.1; using 192.168.1.5 instead (on interface enp0s3)
# 24/12/24 14:57:47 WARN Utils: Set SPARK_LOCAL_IP if you need to bind to another address
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 24/12/24 14:57:48 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable

# %% [markdown]
# ## Read a dataset

# %%
df = spark.read.csv('BTC-USD.csv', inferSchema = True, header = True)
# Out:
# [Stage 0:>                                                          (0 + 1) / 1]

# %% [markdown]
# ## 1. What are the columns names?

# %%
df.columns
# Out:
# ['Date', 'Open', 'High', 'Low', 'Close', 'Volume', 'Dividends', 'Stock Splits']

# %% [markdown]
# ## 2. What does the Schema look like?

# %%
df.printSchema()
# Out:
# root
#  |-- Date: date (nullable = true)
#  |-- Open: double (nullable = true)
#  |-- High: double (nullable = true)
#  |-- Low: double (nullable = true)
#  |-- Close: double (nullable = true)
#  |-- Volume: long (nullable = true)
#  |-- Dividends: integer (nullable = true)
#  |-- Stock Splits: integer (nullable = true)

# %% [markdown]
# ## 3. Display the first 15 rows

# %%
df.show(15)
# Out:
# +----------+----------------+----------------+----------------+----------------+-----------+---------+------------+
# |      Date|            Open|            High|             Low|           Close|     Volume|Dividends|Stock Splits|
# +----------+----------------+----------------+----------------+----------------+-----------+---------+------------+
# |2019-05-31| 8320.2861328125| 8586.6591796875|   8172.55078125|  8574.501953125|25365190957|        0|           0|
# |2019-06-01|   8573.83984375| 8625.6005859375|     8481.578125| 8564.0166015625|22488303544|        0|           0|
# |2019-06-02| 8565.4736328125| 8809.3037109375| 8561.2353515625| 8742.9580078125|20266216022|        0|           0|
# |2019-06-03| 8741.7470703125|          8743.5|  8204.185546875| 8208.9951171875|22004511436|        0|           0|
# |2019-06-04| 8210.9853515625| 8210.9853515625|7564.48876953125|7707.77099609375|24609731549|        0|           0|
# |2019-06-05|7704.34326171875|7901.84912109375|7668.66845703125| 7824.2314453125|21760923463|        0|           0|
# |2019-06-06|7819.63330078125| 7937.3408203125|7571.47119140625|    7822.0234375|19474611077|        0|           0|
# |2019-06-07| 7826.9013671875| 8126.1533203125|7788.37353515625|  8043.951171875|19141423231|        0|           0|
# |2019-06-08|8036.77490234375|8076.89111328125|7837.61083984375| 7954.1279296875|16522722810|        0|           0|
# |2019-06-09| 7949.6748046875|7975.97412109375| 7583.2197265625| 7688.0771484375|16610726547|        0|           0|
# |2019-06-10|7692.28466796875|8031.90966796875|7586.73095703125|8000.32958984375|18689275117|        0|           0|
# |2019-06-11|8004.24365234375|8026.39404296875| 7772.8037109375|7927.71435546875|17107279932|        0|           0|
# |2019-06-12|7925.43408203125|    8196.6484375|7862.35986328125|  8145.857421875|19034432883|        0|           0|
# |2019-06-13|8145.54541015625| 8311.5673828125|8087.06103515625|  8230.923828125|18669407147|        0|           0|
# |2019-06-14|    8230.8984375|   8710.63671875|8183.39306640625| 8693.8330078125|19831162906|        0|           0|
# +----------+----------------+----------------+----------------+----------------+-----------+---------+------------+
# only showing top 15 rows

# %% [markdown]
# ## 4. Describe the dataset in statistical measurements

# %%
df.describe().show()
# Out:
# 24/12/24 14:58:04 WARN SparkStringUtils: Truncated the string representation of a plan since it was too large. This behavior can be adjusted by setting 'spark.sql.debug.maxToStringFields'.
# +-------+------------------+------------------+------------------+------------------+--------------------+---------+------------+
# |summary|              Open|              High|               Low|             Close|              Volume|Dividends|Stock Splits|
# +-------+------------------+------------------+------------------+------------------+--------------------+---------+------------+
# |  count|               759|               759|               759|               759|                 759|      759|         759|
# |   mean|18881.256430644764|19422.984229609272|18271.106332731186| 18911.30140462883|3.559935378705006...|      0.0|         0.0|
# | stddev| 16221.57494286444|16755.792555279113|15566.983081696353|16222.805201441279|2.213068308485810...|      0.0|         0.0|
# |    min|       5002.578125|    5331.833984375|  4106.98095703125|   4970.7880859375|         11445355859|        0|           0|
# |    max|    63523.75390625|    64863.09765625|    62208.96484375|    63503.45703125|        350967941479|        0|           0|
# +-------+------------------+------------------+------------------+------------------+--------------------+---------+------------+

# %% [markdown]
# ## 5. Reshape the results of the previous question into a suitable format

# %%
df.describe().select(
    col("summary"),
    format_number(col("Open").cast("float"), 2).alias("Open"),
    format_number(col("High").cast("float"), 2).alias("High"),
    format_number(col("Low").cast("float"), 2).alias("Low"),
    format_number(col("Close").cast("float"), 2).alias("Close"),
    format_number(col("Volume").cast("float"), 2).alias("Volume"),
    format_number(col("Dividends").cast("float"), 2).alias("Dividends"),
    format_number(col("Stock Splits").cast("float"), 2).alias("Stock Splits")
).show()
# Out:
# +-------+---------+---------+---------+---------+------------------+---------+------------+
# |summary|     Open|     High|      Low|    Close|            Volume|Dividends|Stock Splits|
# +-------+---------+---------+---------+---------+------------------+---------+------------+
# |  count|   759.00|   759.00|   759.00|   759.00|            759.00|   759.00|      759.00|
# |   mean|18,881.26|19,422.98|18,271.11|18,911.30| 35,599,351,808.00|     0.00|        0.00|
# | stddev|16,221.58|16,755.79|15,566.98|16,222.81| 22,130,683,904.00|     0.00|        0.00|
# |    min| 5,002.58| 5,331.83| 4,106.98| 4,970.79| 11,445,355,520.00|     0.00|        0.00|
# |    max|63,523.75|64,863.10|62,208.96|63,503.46|350,967,955,456.00|     0.00|        0.00|
# +-------+---------+---------+---------+---------+------------------+---------+------------+

# %% [markdown]
# ## 6. Add a new detail that displays the ratio of the Low Price versus Close

# %%
df = df.withColumn("Low_to_Close_Ratio", col("Low") / col("Close"))

df.show(15)
# Out:
# +----------+----------------+----------------+----------------+----------------+-----------+---------+------------+------------------+
# |      Date|            Open|            High|             Low|           Close|     Volume|Dividends|Stock Splits|Low_to_Close_Ratio|
# +----------+----------------+----------------+----------------+----------------+-----------+---------+------------+------------------+
# |2019-05-31| 8320.2861328125| 8586.6591796875|   8172.55078125|  8574.501953125|25365190957|        0|           0|0.9531225050653225|
# |2019-06-01|   8573.83984375| 8625.6005859375|     8481.578125| 8564.0166015625|22488303544|        0|           0|0.9903738537186559|
# |2019-06-02| 8565.4736328125| 8809.3037109375| 8561.2353515625| 8742.9580078125|20266216022|        0|           0|0.9792149686539021|
# |2019-06-03| 8741.7470703125|          8743.5|  8204.185546875| 8208.9951171875|22004511436|        0|           0|0.9994141097364732|
# |2019-06-04| 8210.9853515625| 8210.9853515625|7564.48876953125|7707.77099609375|24609731549|        0|           0|0.9814106793474904|
# |2019-06-05|7704.34326171875|7901.84912109375|7668.66845703125| 7824.2314453125|21760923463|        0|           0|0.9801177931189078|
# |2019-06-06|7819.63330078125| 7937.3408203125|7571.47119140625|    7822.0234375|19474611077|        0|           0|0.9679683590702933|
# |2019-06-07| 7826.9013671875| 8126.1533203125|7788.37353515625|  8043.951171875|19141423231|        0|           0|0.9682273510544972|
# |2019-06-08|8036.77490234375|8076.89111328125|7837.61083984375| 7954.1279296875|16522722810|        0|           0|0.9853513683871152|
# |2019-06-09| 7949.6748046875|7975.97412109375| 7583.2197265625| 7688.0771484375|16610726547|        0|           0|0.9863610341245976|
# |2019-06-10|7692.28466796875|8031.90966796875|7586.73095703125|8000.32958984375|18689275117|        0|           0|0.9483023007780136|
# |2019-06-11|8004.24365234375|8026.39404296875| 7772.8037109375|7927.71435546875|17107279932|        0|           0|0.9804596082066972|
# |2019-06-12|7925.43408203125|    8196.6484375|7862.35986328125|  8145.857421875|19034432883|        0|           0|  0.96519733357566|
# |2019-06-13|8145.54541015625| 8311.5673828125|8087.06103515625|  8230.923828125|18669407147|        0|           0| 0.982521671203277|
# |2019-06-14|    8230.8984375|   8710.63671875|8183.39306640625| 8693.8330078125|19831162906|        0|           0|0.9412871237637581|
# +----------+----------------+----------------+----------------+----------------+-----------+---------+------------+------------------+
# only showing top 15 rows

# %% [markdown]
# ## 7. What day had the peak volume?

# %%
peak_volume_row = df.orderBy(col("Volume").desc()).first()

peak_date = peak_volume_row["Date"]
peak_volume = peak_volume_row["Volume"]

print(f"The day with the peak volume is {peak_date} with a volume of {peak_volume}.")
# Out:
# The day with the peak volume is 2021-02-26 with a volume of 350967941479.

# %% [markdown]
# ## 8. What is the max of the Volume column?

# %%
df.select((max("Volume")).alias('The maximum Volume')).show()
# Out:
# +------------------+
# |The maximum Volume|
# +------------------+
# |      350967941479|
# +------------------+

# %% [markdown]
# ## 9. What is the average and the standard deviation of the opening?

# %%
df.select(mean("Open").alias('Average of the Open column'),
          stddev("Open").alias('Standard deviation of the Open column')).show()
# Out:
# +--------------------------+-------------------------------------+
# |Average of the Open column|Standard deviation of the Open column|
# +--------------------------+-------------------------------------+
# |        18881.256430644764|                    16221.57494286444|
# +--------------------------+-------------------------------------+

# %% [markdown]
# ## 10. How many days was the opening lower than 10,000 dollars?

# %%
days_below_10000 = df.filter(col("Open") < 10000).count()
days_below_10000
# Out:
# 337

# %% [markdown]
# ## 11. What percentage of the time was the closing greater than 32 dollars?

# %%
total_days = df.count()

days_above_32 = df.filter(col("Close") > 32).count()

percentage_above_32 = (days_above_32 / total_days) * 100

print(f"The percentage of days where the closing price was greater than $32 is {percentage_above_32:.2f}%.")
# Out:
# The percentage of days where the closing price was greater than $32 is 100.00%.

# %% [markdown]
# ## 12. How many distinct volumes?

# %%
distinct_volumes = df.select("Volume").distinct().count()
distinct_volumes
# Out:
# 759

# %% [markdown]
# #### another sol.

# %%
df.select(countDistinct('Volume').alias('Number of distinct volumes')).show()
# Out:
# +--------------------------+
# |Number of distinct volumes|
# +--------------------------+
# |                       759|
# +--------------------------+

# %% [markdown]
# ## 13. What is the min opening per year?

# %%
min_open_per_year = (
    df.withColumn("Year", year(col("Date")))  
      .groupBy("Year")                        
      .agg(min("Open").alias("Min_Open"))     
      .orderBy("Year")                        
)

min_open_per_year.show()
# Out:
# +----+---------------+
# |Year|       Min_Open|
# +----+---------------+
# |2019|6647.6982421875|
# |2020|    5002.578125|
# |2021|28994.009765625|
# +----+---------------+

# %% [markdown]
# ## 14. What is the highest closing for each day of the year?

# %%
df = df.withColumn("Day",dayofyear("Date"))

HighestDays = df.select("Day","Close").groupBy("Day").max()
HighestDays.select("Day","max(Close)").orderBy('Day').show(366)
# Out:
# +---+----------------+
# |Day|      max(Close)|
# +---+----------------+
# |  1|  29374.15234375|
# |  2| 32127.267578125|
# |  3|   32782.0234375|
# |  4|   31971.9140625|
# |  5|   33992.4296875|
# |  6|  36824.36328125|
# |  7|  39371.04296875|
# |  8|    40797.609375|
# |  9|    40254.546875|
# | 10|  38356.44140625|
# | 11|     35566.65625|
# | 12|   33922.9609375|
# | 13|    37316.359375|
# | 14|    39187.328125|
# | 15|   36825.3671875|
# | 16|    36178.140625|
# | 17|  35791.27734375|
# | 18|  36630.07421875|
# | 19|   36069.8046875|
# | 20|        35547.75|
# | 21|  30825.69921875|
# | 22|  33005.76171875|
# | 23| 32067.642578125|
# | 24|  32289.37890625|
# | 25| 32366.392578125|
# | 26| 32569.849609375|
# | 27|    30432.546875|
# | 28|  31649.60546875|
# | 29|  34316.38671875|
# | 30|   34269.5234375|
# | 31|    33114.359375|
# | 32|  33537.17578125|
# | 33|   35510.2890625|
# | 34|  37472.08984375|
# | 35|  36926.06640625|
# | 36|  38144.30859375|
# | 37|  39266.01171875|
# | 38|  38903.44140625|
# | 39|  46196.46484375|
# | 40|  46481.10546875|
# | 41|  44918.18359375|
# | 42|  47909.33203125|
# | 43|   47504.8515625|
# | 44|    47105.515625|
# | 45|   48717.2890625|
# | 46|  47945.05859375|
# | 47|  49199.87109375|
# | 48|   52149.0078125|
# | 49|    51679.796875|
# | 50|   55888.1328125|
# | 51|  56099.51953125|
# | 52|   57539.9453125|
# | 53|   54207.3203125|
# | 54|  48824.42578125|
# | 55|  49705.33203125|
# | 56|   47093.8515625|
# | 57|  46339.76171875|
# | 58|    46188.453125|
# | 59|  45137.76953125|
# | 60|   49631.2421875|
# | 61|  48378.98828125|
# | 62|   50538.2421875|
# | 63|  48561.16796875|
# | 64|   48927.3046875|
# | 65|   48912.3828125|
# | 66|  51206.69140625|
# | 67|   52246.5234375|
# | 68|   54824.1171875|
# | 69|  56008.55078125|
# | 70|  57805.12109375|
# | 71|  57332.08984375|
# | 72|   61243.0859375|
# | 73|  59302.31640625|
# | 74|  55907.19921875|
# | 75|  56804.90234375|
# | 76|  58870.89453125|
# | 77|    57858.921875|
# | 78|  58346.65234375|
# | 79|  58313.64453125|
# | 80|    57523.421875|
# | 81|  54529.14453125|
# | 82|   54738.9453125|
# | 83|    52774.265625|
# | 84|  51704.16015625|
# | 85|      55137.3125|
# | 86|  55973.51171875|
# | 87|  55950.74609375|
# | 88|  57750.19921875|
# | 89|  58917.69140625|
# | 90|  58918.83203125|
# | 91|  59095.80859375|
# | 92|      59384.3125|
# | 93|    57603.890625|
# | 94|   58758.5546875|
# | 95|  59057.87890625|
# | 96|    58192.359375|
# | 97|      56048.9375|
# | 98|    58323.953125|
# | 99|  58245.00390625|
# |100|    59793.234375|
# |101|  60204.96484375|
# |102|    59893.453125|
# |103|  63503.45703125|
# |104|   63109.6953125|
# |105|  63314.01171875|
# |106|   61572.7890625|
# |107|   60683.8203125|
# |108|  56216.18359375|
# |109|    55724.265625|
# |110|     56473.03125|
# |111|  53906.08984375|
# |112|   51762.2734375|
# |113|  51093.65234375|
# |114|   50050.8671875|
# |115|  49004.25390625|
# |116|  54021.75390625|
# |117|   55033.1171875|
# |118|    54824.703125|
# |119|    53555.109375|
# |120|  57750.17578125|
# |121|  57828.05078125|
# |122|    56631.078125|
# |123|  57200.29296875|
# |124|   53333.5390625|
# |125|   57424.0078125|
# |126|    56396.515625|
# |127|  57356.40234375|
# |128|  58803.77734375|
# |129|  58232.31640625|
# |130|    55859.796875|
# |131|  56704.57421875|
# |132|  49150.53515625|
# |133|  49716.19140625|
# |134|  49880.53515625|
# |135|      46760.1875|
# |136|  46456.05859375|
# |137|  43537.51171875|
# |138|  42909.40234375|
# |139|  37002.44140625|
# |140|  40782.73828125|
# |141|  37304.69140625|
# |142|   37536.6328125|
# |143|  34770.58203125|
# |144|  38705.98046875|
# |145|  38402.22265625|
# |146|  39294.19921875|
# |147|     38436.96875|
# |148|  35697.60546875|
# |149|  34616.06640625|
# |150|  35678.12890625|
# |151|  37332.85546875|
# |152|  36684.92578125|
# |153|   37575.1796875|
# |154|    39208.765625|
# |155|     36894.40625|
# |156|  35551.95703125|
# |157|  35862.37890625|
# |158|  33560.70703125|
# |159|   33472.6328125|
# |160|  37345.12109375|
# |161|  36702.59765625|
# |162|   37334.3984375|
# |163|    35552.515625|
# |164|    39097.859375|
# |165|   40218.4765625|
# |166|  40406.26953125|
# |167|      38347.0625|
# |168|  38053.50390625|
# |169|  35787.24609375|
# |170|  35615.87109375|
# |171|    35698.296875|
# |172| 31676.693359375|
# |173|  32505.66015625|
# |174|  33723.02734375|
# |175|      34662.4375|
# |176| 31637.779296875|
# |177|  32186.27734375|
# |178|  34649.64453125|
# |179|   34434.3359375|
# |180|  35867.77734375|
# |181|   35040.8359375|
# |182|   33572.1171875|
# |183| 10801.677734375|
# |184|  11961.26953125|
# |185|      11215.4375|
# |186|10978.4599609375|
# |187|  11208.55078125|
# |188|11450.8466796875|
# |189|12285.9580078125|
# |190|      12573.8125|
# |191|12156.5126953125|
# |192| 11358.662109375|
# |193| 11815.986328125|
# |194|  11392.37890625|
# |195|  10256.05859375|
# |196|  10895.08984375|
# |197| 9477.6416015625|
# |198|  9693.802734375|
# |199| 10666.482421875|
# |200| 10530.732421875|
# |201|10767.1396484375|
# |202|  10599.10546875|
# |203|10343.1064453125|
# |204|  9900.767578125|
# |205|   9811.92578125|
# |206|  9911.841796875|
# |207| 9870.3037109375|
# |208| 9905.1669921875|
# |209| 10990.873046875|
# |210|10912.8232421875|
# |211|11100.4677734375|
# |212|11111.2138671875|
# |213| 11323.466796875|
# |214|11759.5927734375|
# |215|11053.6142578125|
# |216|11246.3486328125|
# |217|11805.6533203125|
# |218|11747.0224609375|
# |219|     11941.96875|
# |220|11966.4072265625|
# |221|11862.9365234375|
# |222|11675.7392578125|
# |223| 11878.111328125|
# |224| 11410.525390625|
# |225|11584.9345703125|
# |226|11784.1376953125|
# |227|  11768.87109375|
# |228|11865.6982421875|
# |229|11892.8037109375|
# |230|  12254.40234375|
# |231|11991.2333984375|
# |232| 11758.283203125|
# |233|11878.3720703125|
# |234|11592.4892578125|
# |235|11681.8251953125|
# |236|  11664.84765625|
# |237| 11774.595703125|
# |238| 11366.134765625|
# |239|  11488.36328125|
# |240|11323.3974609375|
# |241|         11542.5|
# |242| 11506.865234375|
# |243| 11711.505859375|
# |244|   11680.8203125|
# |245| 11970.478515625|
# |246|11414.0341796875|
# |247|10594.4931640625|
# |248| 10575.533203125|
# |249| 10353.302734375|
# |250|10517.2548828125|
# |251|10441.2763671875|
# |252| 10334.974609375|
# |253|  10242.34765625|
# |254| 10363.138671875|
# |255| 10410.126953125|
# |256|10442.1708984375|
# |257| 10358.048828125|
# |258| 10680.837890625|
# |259| 10796.951171875|
# |260|10974.9052734375|
# |261| 10948.990234375|
# |262|   10944.5859375|
# |263|11094.3466796875|
# |264| 10938.271484375|
# |265| 10462.259765625|
# |266|10538.4599609375|
# |267|10225.8642578125|
# |268| 10745.548828125|
# |269|10702.2900390625|
# |270|      10754.4375|
# |271|10774.4267578125|
# |272|10721.3271484375|
# |273| 10848.830078125|
# |274|10787.6181640625|
# |275| 10623.330078125|
# |276|   10585.1640625|
# |277|10565.4931640625|
# |278|10684.4287109375|
# |279|10804.0009765625|
# |280|   10621.6640625|
# |281|  10679.13671875|
# |282|10923.6279296875|
# |283| 8586.4736328125|
# |284| 11296.361328125|
# |285| 11384.181640625|
# |286|  8321.005859375|
# |287| 8374.6865234375|
# |288|11429.5068359375|
# |289| 11495.349609375|
# |290| 11322.123046875|
# |291|   11358.1015625|
# |292|    11483.359375|
# |293| 11742.037109375|
# |294|11916.3349609375|
# |295| 12823.689453125|
# |296|12965.8916015625|
# |297|   12931.5390625|
# |298|      13108.0625|
# |299| 13031.173828125|
# |300| 13075.248046875|
# |301|     13654.21875|
# |302|  13271.28515625|
# |303|   13437.8828125|
# |304|13546.5224609375|
# |305|13780.9951171875|
# |306|    13737.109375|
# |307|13550.4892578125|
# |308|  13950.30078125|
# |309|  14133.70703125|
# |310|15579.8486328125|
# |311| 15565.880859375|
# |312|  14833.75390625|
# |313|15479.5673828125|
# |314|15332.3154296875|
# |315|  15290.90234375|
# |316|  15701.33984375|
# |317|     16276.34375|
# |318|  16317.80859375|
# |319| 16068.138671875|
# |320| 15955.587890625|
# |321| 16716.111328125|
# |322|     17645.40625|
# |323| 17804.005859375|
# |324|  17817.08984375|
# |325| 18621.314453125|
# |326| 18642.232421875|
# |327| 18370.001953125|
# |328|  18364.12109375|
# |329|  19107.46484375|
# |330|  18732.12109375|
# |331| 17150.623046875|
# |332|  17108.40234375|
# |333|   17717.4140625|
# |334|    18177.484375|
# |335|   19625.8359375|
# |336| 18802.998046875|
# |337| 19201.091796875|
# |338|   19445.3984375|
# |339|    18699.765625|
# |340|  19154.23046875|
# |341|  19345.12109375|
# |342| 19191.630859375|
# |343|  18321.14453125|
# |344| 18553.916015625|
# |345|   18264.9921875|
# |346| 18058.904296875|
# |347|     18803.65625|
# |348|   19142.3828125|
# |349|  19246.64453125|
# |350| 19417.076171875|
# |351|  21310.59765625|
# |352| 22805.162109375|
# |353|   23137.9609375|
# |354|  23869.83203125|
# |355| 23477.294921875|
# |356|  22803.08203125|
# |357| 23783.029296875|
# |358| 23241.345703125|
# |359|  23735.94921875|
# |360| 24664.791015625|
# |361| 26437.037109375|
# |362| 26272.294921875|
# |363|  27084.80859375|
# |364|      27362.4375|
# |365|    28840.953125|
# |366| 29001.720703125|
# +---+----------------+
